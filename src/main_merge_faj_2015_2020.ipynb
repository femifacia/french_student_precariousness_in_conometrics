# %% [markdown]
# # Main imports

# %%
import os
import pandas as pd 
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
from tqdm import tqdm
from collections import defaultdict
import numpy as np


pd.options.display.max_columns = 200
pd.options.display.max_rows = 50

# %% [markdown]
# # Load FAJ 2015 2020

# %%
path_df = "../database/cleaned/cleaned_faj2015_2020.csv"

faj_df = pd.read_csv(path_df, index_col=0)

# %%
faj_df
# Out:
#             Budget FAJ (en euros)  \
# Ain                     457200.00
# Allier                  198034.00
# Ardèche                 271930.93
# Cantal                  108000.00
# Drôme                   505023.39
# ...                           ...
# Guadeloupe              380267.34
# Martinique              355000.00
# Guyane                  255074.04
# La Réunion              400000.00
# Mayotte                       NaN
#
#             Montant des aides individuelles attribuées (en euros)  \
# Ain                                                 252328.00
# Allier                                              147222.06
# Ardèche                                             152403.00
# Cantal                                               32147.30
# Drôme                                               196800.26
# ...                                                       ...
# Guadeloupe                                          344722.03
# Martinique                                                NaN
# Guyane                                              234381.00
# La Réunion                                          211471.15
# Mayotte                                                   NaN
#
#             Nombre d'aides individuelles attribuées (2)  \
# Ain                                              1520.0
# Allier                                           1397.0
# Ardèche                                          1203.0
# Cantal                                            195.0
# Drôme                                             891.0
# ...                                                 ...
# Guadeloupe                                       1661.0
# Martinique                                        704.0
# Guyane                                            490.0
# La Réunion                                       1152.0
# Mayotte                                             NaN
#
#             Montant moyen de l'aide individuelle attribuée (en euros)  \
# Ain                                                    166.01
# Allier                                                 105.38
# Ardèche                                                126.69
# Cantal                                                 164.86
# Drôme                                                  220.88
# ...                                                       ...
# Guadeloupe                                             207.54
# Martinique                                                NaN
# Guyane                                                 478.33
# La Réunion                                             183.57
# Mayotte                                                   NaN
#
#             Nombre de bénéficiaires du FAJ  \
# Ain                                  971.0
# Allier                               778.0
# Ardèche                              694.0
# Cantal                               155.0
# Drôme                                845.0
# ...                                    ...
# Guadeloupe                           616.0
# Martinique                           704.0
# Guyane                               490.0
# La Réunion                          1019.0
# Mayotte                                NaN
#
#             Part de l'ensemble des jeunes de 20 à 24 ans vivant chez les parents en %  \
# Ain                                                     55.59
# Allier                                                  40.77
# Ardèche                                                 53.46
# Cantal                                                  42.94
# Drôme                                                   51.33
# ...                                                       ...
# Guadeloupe                                              70.90
# Martinique                                              73.64
# Guyane                                                  50.97
# La Réunion                                              60.64
# Mayotte                                                   NaN
#
#             Population étudiante  Taux pauvreté département  \
# Ain                       3183.0                       10.5
# Allier                    3857.0                       15.3
# Ardèche                   1415.0                       14.3
# Cantal                    1431.0                       13.2
# Drôme                     7920.0                       14.4
# ...                          ...                        ...
# Guadeloupe                9603.0                        NaN
# Martinique                8628.0                       26.7
# Guyane                    4250.0                        NaN
# La Réunion               21426.0                       35.6
# Mayotte                   1655.0                        NaN
#
#             Population étudiante sous le seuil de pauvreté
# Ain                                                334.215
# Allier                                             590.121
# Ardèche                                            202.345
# Cantal                                             188.892
# Drôme                                             1140.480
# ...                                                    ...
# Guadeloupe                                           0.000
# Martinique                                        2303.676
# Guyane                                               0.000
# La Réunion                                        7627.656
# Mayotte                                              0.000
#
# [101 rows x 9 columns]

# %% [markdown]
# # Cost rent

# %%
path_df = "../database/cleaned/cleaned_rent_cost_student.csv"

cost_rent_df = pd.read_csv(path_df, index_col=0)

# %%
for i in faj_df.index:
    if i not in cost_rent_df.index:
        print('Dieu', i)

# %%
for i in faj_df.index:
    if i not in cost_rent_df.index:
        print('Dieu', i)

# %%
cost_rent_df.loc["Ain",["Loyer m2 moyen\r appartement","Loyer m2 moyen\r maison"]][0]
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_15320\2615587039.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cost_rent_df.loc["Ain",["Loyer m2 moyen\r appartement","Loyer m2 moyen\r maison"]][0]
# np.float64(13.6)

# %%
cost_arr_appartement = []
cost_arr_maison = []

for i in faj_df.index:
    if i in cost_rent_df.index:
        cost_arr_appartement.append(cost_rent_df.loc[i,["Loyer m2 moyen\r appartement"]].values[0])
        cost_arr_maison.append(cost_rent_df.loc[i,["Loyer m2 moyen\r maison"]].values[0])
    else:
        cost_arr_appartement.append(np.nan)
        cost_arr_maison.append(np.nan)

# %%
cost_arr_appartement
cost_arr_maison
# Out:
# [np.float64(13.7),
#  np.float64(9.8),
#  np.float64(11.0),
#  np.float64(9.7),
#  np.float64(11.9),
#  np.float64(13.4),
#  np.float64(10.8),
#  np.float64(9.8),
#  np.float64(10.7),
#  np.float64(15.0),
#  np.float64(13.2),
#  np.float64(18.4),
#  np.float64(11.6),
#  np.float64(12.4),
#  np.float64(11.3),
#  np.float64(9.7),
#  np.float64(9.7),
#  np.float64(10.2),
#  np.float64(10.6),
#  np.float64(12.1),
#  np.float64(10.2),
#  np.float64(11.1),
#  np.float64(11.5),
#  np.float64(11.8),
#  np.float64(9.8),
#  np.float64(11.8),
#  np.float64(9.0),
#  np.float64(11.2),
#  np.float64(10.0),
#  np.float64(11.5),
#  np.float64(13.9),
#  np.float64(14.0),
#  np.float64(9.5),
#  np.float64(10.6),
#  np.float64(11.0),
#  np.float64(9.2),
#  np.float64(11.3),
#  np.float64(9.3),
#  np.float64(11.7),
#  np.float64(12.3),
#  np.float64(13.3),
#  np.float64(10.0),
#  np.float64(10.1),
#  np.float64(11.2),
#  np.float64(13.2),
#  np.float64(10.8),
#  np.float64(10.5),
#  np.float64(28.4),
#  np.float64(16.0),
#  np.float64(20.1),
#  np.float64(18.4),
#  np.float64(28.5),
#  np.float64(20.7),
#  np.float64(23.4),
#  np.float64(19.4),
#  np.float64(12.0),
#  np.float64(11.8),
#  np.float64(10.0),
#  np.float64(9.2),
#  np.float64(12.0),
#  np.float64(9.6),
#  np.float64(11.7),
#  np.float64(9.9),
#  np.float64(8.9),
#  np.float64(9.9),
#  np.float64(13.3),
#  np.float64(11.8),
#  np.float64(10.0),
#  np.float64(12.9),
#  np.float64(9.3),
#  np.float64(9.8),
#  np.float64(9.6),
#  np.float64(9.7),
#  np.float64(10.5),
#  np.float64(10.3),
#  np.float64(11.6),
#  np.float64(12.5),
#  np.float64(10.3),
#  np.float64(12.7),
#  np.float64(9.9),
#  np.float64(9.7),
#  np.float64(10.7),
#  np.float64(11.1),
#  np.float64(10.3),
#  np.float64(10.7),
#  np.float64(12.2),
#  np.float64(10.6),
#  np.float64(9.0),
#  np.float64(9.5),
#  np.float64(11.1),
#  np.float64(11.4),
#  np.float64(12.5),
#  np.float64(19.8),
#  np.float64(15.8),
#  np.float64(15.0),
#  np.float64(12.5),
#  np.float64(13.0),
#  np.float64(13.0),
#  np.float64(14.0),
#  np.float64(12.0),
#  np.float64(13.0)]

# %%
faj_df["Loyer moyen m2 appartement"] = cost_arr_appartement
faj_df["Loyer moyen m2 maison"] = cost_arr_maison

# %%
faj_df
# Out:
#             Budget FAJ (en euros)  \
# Ain                     457200.00
# Allier                  198034.00
# Ardèche                 271930.93
# Cantal                  108000.00
# Drôme                   505023.39
# ...                           ...
# Guadeloupe              380267.34
# Martinique              355000.00
# Guyane                  255074.04
# La Réunion              400000.00
# Mayotte                       NaN
#
#             Montant des aides individuelles attribuées (en euros)  \
# Ain                                                 252328.00
# Allier                                              147222.06
# Ardèche                                             152403.00
# Cantal                                               32147.30
# Drôme                                               196800.26
# ...                                                       ...
# Guadeloupe                                          344722.03
# Martinique                                                NaN
# Guyane                                              234381.00
# La Réunion                                          211471.15
# Mayotte                                                   NaN
#
#             Nombre d'aides individuelles attribuées (2)  \
# Ain                                              1520.0
# Allier                                           1397.0
# Ardèche                                          1203.0
# Cantal                                            195.0
# Drôme                                             891.0
# ...                                                 ...
# Guadeloupe                                       1661.0
# Martinique                                        704.0
# Guyane                                            490.0
# La Réunion                                       1152.0
# Mayotte                                             NaN
#
#             Montant moyen de l'aide individuelle attribuée (en euros)  \
# Ain                                                    166.01
# Allier                                                 105.38
# Ardèche                                                126.69
# Cantal                                                 164.86
# Drôme                                                  220.88
# ...                                                       ...
# Guadeloupe                                             207.54
# Martinique                                                NaN
# Guyane                                                 478.33
# La Réunion                                             183.57
# Mayotte                                                   NaN
#
#             Nombre de bénéficiaires du FAJ  \
# Ain                                  971.0
# Allier                               778.0
# Ardèche                              694.0
# Cantal                               155.0
# Drôme                                845.0
# ...                                    ...
# Guadeloupe                           616.0
# Martinique                           704.0
# Guyane                               490.0
# La Réunion                          1019.0
# Mayotte                                NaN
#
#             Part de l'ensemble des jeunes de 20 à 24 ans vivant chez les parents en %  \
# Ain                                                     55.59
# Allier                                                  40.77
# Ardèche                                                 53.46
# Cantal                                                  42.94
# Drôme                                                   51.33
# ...                                                       ...
# Guadeloupe                                              70.90
# Martinique                                              73.64
# Guyane                                                  50.97
# La Réunion                                              60.64
# Mayotte                                                   NaN
#
#             Population étudiante  Taux pauvreté département  \
# Ain                       3183.0                       10.5
# Allier                    3857.0                       15.3
# Ardèche                   1415.0                       14.3
# Cantal                    1431.0                       13.2
# Drôme                     7920.0                       14.4
# ...                          ...                        ...
# Guadeloupe                9603.0                        NaN
# Martinique                8628.0                       26.7
# Guyane                    4250.0                        NaN
# La Réunion               21426.0                       35.6
# Mayotte                   1655.0                        NaN
#
#             Population étudiante sous le seuil de pauvreté  \
# Ain                                                334.215
# Allier                                             590.121
# Ardèche                                            202.345
# Cantal                                             188.892
# Drôme                                             1140.480
# ...                                                    ...
# Guadeloupe                                           0.000
# Martinique                                        2303.676
# Guyane                                               0.000
# La Réunion                                        7627.656
# Mayotte                                              0.000
#
#             Loyer moyen m2 appartement  Loyer moyen m2 maison
# Ain                               13.6                   13.7
# Allier                            10.8                    9.8
# Ardèche                           10.4                   11.0
# Cantal                             9.6                    9.7
# Drôme                             11.3                   11.9
# ...                                ...                    ...
# Guadeloupe                        12.0                   13.0
# Martinique                        12.0                   13.0
# Guyane                            13.0                   14.0
# La Réunion                        10.0                   12.0
# Mayotte                           13.0                   13.0
#
# [101 rows x 11 columns]

# %% [markdown]
# # Merge Energy consumption

# %%
path_df = "../database/cleaned/consommation_energetique.csv"
energy_df = pd.read_csv(path_df)
energy_df.dtypes
# Out:
# Consommation energetique Departement (Mwh)    float64
# Population departement                          int64
# dtype: object

# %%
consomme_moyen = []


for i in energy_df.index:
    consomme_moyen.append(energy_df.loc[i][0]/energy_df.loc[i][1])
consomme_moyen
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_15320\7969839.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   consomme_moyen.append(energy_df.loc[i][0]/energy_df.loc[i][1])
# [np.float64(4.395063689979555),
#  np.float64(5.073961465404198),
#  np.float64(3.6967387618657255),
#  np.float64(3.4349827922662923),
#  np.float64(4.125585521247786),
#  np.float64(3.888683306265823),
#  np.float64(4.3591531167564295),
#  np.float64(3.947151151567364),
#  np.float64(4.444951565799846),
#  np.float64(4.2199306556882235),
#  np.float64(4.4066431874876635),
#  np.float64(4.587153652227175),
#  np.float64(4.688141749251642),
#  np.float64(3.9884778443200126),
#  np.float64(4.053572750470985),
#  np.float64(4.92083183654346),
#  np.float64(3.635555187761642),
#  np.float64(5.216047112948083),
#  np.float64(5.012917071167538),
#  np.float64(4.654387936966665),
#  np.float64(4.009124723293404),
#  np.float64(3.9917090840715175),
#  np.float64(3.8883995113230965),
#  np.float64(4.1639577911742425),
#  np.float64(4.995884759806269),
#  np.float64(4.790510872569493),
#  np.float64(4.595795194721248),
#  np.float64(4.399662268616724),
#  np.float64(4.713925296543082),
#  np.float64(4.792323553773391),
#  np.float64(3.19265549019364),
#  np.float64(2.8831626031374564),
#  np.float64(5.01280441201208),
#  np.float64(4.505282850243133),
#  np.float64(4.57668169095223),
#  np.float64(4.205304453044593),
#  np.float64(5.582982634276854),
#  np.float64(4.485329394204885),
#  np.float64(5.818487502617916),
#  np.float64(3.9426941641490307),
#  np.float64(4.737879743952076),
#  np.float64(4.6696069440041725),
#  np.float64(4.549899145347033),
#  np.float64(5.20075822070635),
#  np.float64(4.358168821327397),
#  np.float64(5.012171949716756),
#  np.float64(4.202094126024233),
#  np.float64(4.23091799397097),
#  np.float64(4.678510260511873),
#  np.float64(4.901596841603534),
#  np.float64(4.487988545993119),
#  np.float64(4.159671334259768),
#  np.float64(3.583580277726253),
#  np.float64(3.88829747004145),
#  np.float64(4.278317175504216),
#  np.float64(4.55730897684179),
#  np.float64(4.330942258635112),
#  np.float64(4.227619455309952),
#  np.float64(3.9652210729965707),
#  np.float64(4.282592571433215),
#  np.float64(4.529789278992403),
#  np.float64(4.55740239983697),
#  np.float64(4.4072801010529705),
#  np.float64(3.736153074985465),
#  np.float64(4.44477052093402),
#  np.float64(4.558629671097232),
#  np.float64(4.247058096929772),
#  np.float64(4.282431143504492),
#  np.float64(4.568271150262543),
#  np.float64(3.8158248879403227),
#  np.float64(3.892350447764447),
#  np.float64(4.46842895719848),
#  np.float64(4.428688679604947),
#  np.float64(4.032287768513527),
#  np.float64(3.922491271112057),
#  np.float64(4.199117752525335),
#  np.float64(4.208324318598615),
#  np.float64(3.8818914089131993),
#  np.float64(3.9291011188166087),
#  np.float64(3.8641615022515543),
#  np.float64(2.5897449773761045),
#  np.float64(5.303939954157745),
#  np.float64(3.749517991343759),
#  np.float64(4.119928552629454),
#  np.float64(3.8968940592518186),
#  np.float64(4.195028859243502),
#  np.float64(3.779850454089493),
#  np.float64(3.8223447584065595),
#  np.float64(4.321670783038379),
#  np.float64(4.023676607599064),
#  np.float64(3.9982416908108864),
#  np.float64(4.264700417802382),
#  np.float64(4.769783651913433),
#  np.float64(3.59961889656957),
#  np.float64(4.071634232674225),
#  np.float64(4.072030184371153),
#  np.float64(1.8835149351208027),
#  np.float64(1.6881780192400857),
#  np.float64(1.1251099872690988),
#  np.float64(1.4740968307798903),
#  np.float64(0.6663533722327099)]

# %%
faj_df["Consommation énergétique moyenne (MWh)"] = consomme_moyen

# %%
faj_df
# Out:
#             Budget FAJ (en euros)  \
# Ain                     457200.00
# Allier                  198034.00
# Ardèche                 271930.93
# Cantal                  108000.00
# Drôme                   505023.39
# ...                           ...
# Guadeloupe              380267.34
# Martinique              355000.00
# Guyane                  255074.04
# La Réunion              400000.00
# Mayotte                       NaN
#
#             Montant des aides individuelles attribuées (en euros)  \
# Ain                                                 252328.00
# Allier                                              147222.06
# Ardèche                                             152403.00
# Cantal                                               32147.30
# Drôme                                               196800.26
# ...                                                       ...
# Guadeloupe                                          344722.03
# Martinique                                                NaN
# Guyane                                              234381.00
# La Réunion                                          211471.15
# Mayotte                                                   NaN
#
#             Nombre d'aides individuelles attribuées (2)  \
# Ain                                              1520.0
# Allier                                           1397.0
# Ardèche                                          1203.0
# Cantal                                            195.0
# Drôme                                             891.0
# ...                                                 ...
# Guadeloupe                                       1661.0
# Martinique                                        704.0
# Guyane                                            490.0
# La Réunion                                       1152.0
# Mayotte                                             NaN
#
#             Montant moyen de l'aide individuelle attribuée (en euros)  \
# Ain                                                    166.01
# Allier                                                 105.38
# Ardèche                                                126.69
# Cantal                                                 164.86
# Drôme                                                  220.88
# ...                                                       ...
# Guadeloupe                                             207.54
# Martinique                                                NaN
# Guyane                                                 478.33
# La Réunion                                             183.57
# Mayotte                                                   NaN
#
#             Nombre de bénéficiaires du FAJ  \
# Ain                                  971.0
# Allier                               778.0
# Ardèche                              694.0
# Cantal                               155.0
# Drôme                                845.0
# ...                                    ...
# Guadeloupe                           616.0
# Martinique                           704.0
# Guyane                               490.0
# La Réunion                          1019.0
# Mayotte                                NaN
#
#             Part de l'ensemble des jeunes de 20 à 24 ans vivant chez les parents en %  \
# Ain                                                     55.59
# Allier                                                  40.77
# Ardèche                                                 53.46
# Cantal                                                  42.94
# Drôme                                                   51.33
# ...                                                       ...
# Guadeloupe                                              70.90
# Martinique                                              73.64
# Guyane                                                  50.97
# La Réunion                                              60.64
# Mayotte                                                   NaN
#
#             Population étudiante  Taux pauvreté département  \
# Ain                       3183.0                       10.5
# Allier                    3857.0                       15.3
# Ardèche                   1415.0                       14.3
# Cantal                    1431.0                       13.2
# Drôme                     7920.0                       14.4
# ...                          ...                        ...
# Guadeloupe                9603.0                        NaN
# Martinique                8628.0                       26.7
# Guyane                    4250.0                        NaN
# La Réunion               21426.0                       35.6
# Mayotte                   1655.0                        NaN
#
#             Population étudiante sous le seuil de pauvreté  \
# Ain                                                334.215
# Allier                                             590.121
# Ardèche                                            202.345
# Cantal                                             188.892
# Drôme                                             1140.480
# ...                                                    ...
# Guadeloupe                                           0.000
# Martinique                                        2303.676
# Guyane                                               0.000
# La Réunion                                        7627.656
# Mayotte                                              0.000
#
#             Loyer moyen m2 appartement  Loyer moyen m2 maison  \
# Ain                               13.6                   13.7
# Allier                            10.8                    9.8
# Ardèche                           10.4                   11.0
# Cantal                             9.6                    9.7
# Drôme                             11.3                   11.9
# ...                                ...                    ...
# Guadeloupe                        12.0                   13.0
# Martinique                        12.0                   13.0
# Guyane                            13.0                   14.0
# La Réunion                        10.0                   12.0
# Mayotte                           13.0                   13.0
#
#             Consommation énergétique moyenne
# Ain                                 4.395064
# Allier                              5.073961
# Ardèche                             3.696739
# Cantal                              3.434983
# Drôme                               4.125586
# ...                                      ...
# Guadeloupe                          1.883515
# Martinique                          1.688178
# Guyane                              1.125110
# La Réunion                          1.474097
# Mayotte                             0.666353
#
# [101 rows x 12 columns]

# %% [markdown]
# # Add median income per department

# %%
path_df = "../database/cleaned/niveau de vie médian.csv"
money_df = pd.read_csv(path_df)
money_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\james\OneDrive\Documents\french_student_precariousness_in_conometrics\src\main_merge_faj_2015_2020.ipynb Cell 21 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/james/OneDrive/Documents/french_student_precariousness_in_conometrics/src/main_merge_faj_2015_2020.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> path_df = "../database/cleaned/niveau de vie médian.csv"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/james/OneDrive/Documents/french_student_precariousness_in_conometrics/src/main_merge_faj_2015_2020.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> money_df = pd.read_csv(path_df)
#       <a href='vscode-notebook-cell:/c%3A/Users/james/OneDrive/Documents/french_student_precariousness_in_conometrics/src/main_merge_faj_2015_2020.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> money_df.dtypes
#
# File c:\Users\james\OneDrive\Documents\french_student_precariousness_in_conometrics\.venv\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\james\OneDrive\Documents\french_student_precariousness_in_conometrics\.venv\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\james\OneDrive\Documents\french_student_precariousness_in_conometrics\.venv\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\james\OneDrive\Documents\french_student_precariousness_in_conometrics\.venv\lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File c:\Users\james\OneDrive\Documents\french_student_precariousness_in_conometrics\.venv\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 15: invalid continuation byte

# %% [markdown]
# # Save merged df

# %%
path_merged = "../database/cleaned/merged_faj2015_2020.csv"
faj_df.to_csv(path_merged)
