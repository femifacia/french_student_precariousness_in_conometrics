# %% [markdown]
# # main imports

# %%
import os
import pandas as pd 
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
from tqdm import tqdm
from collections import defaultdict
import numpy as np
import statsmodels.formula.api



pd.options.display.max_columns = 200
pd.options.display.max_rows = 50

# %%
df = pd.DataFrame({'x1': [2, 6, 7, 8, 6, 2], 'x2': [4, 2, 9, 1, 7, 2]})
df['y'] = df['x1'] * 2 + df['x2'] * 5 + 0.2 * np.random.randn(len(df)) + 3
model = statsmodels.formula.api.ols('y ~ x1 + x2', data = df)
result = model.fit()

# %%
result.summary()
# Out:
# c:\Users\james\OneDrive\Documents\french_student_precariousness_in_conometrics\.venv\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.328e+04
# Date:                Sun, 17 Nov 2024   Prob (F-statistic):           5.17e-07
# Time:                        21:09:37   Log-Likelihood:                 3.7885
# No. Observations:                   6   AIC:                            -1.577
# Df Residuals:                       3   BIC:                            -2.202
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.0522      0.196     15.602      0.001       2.430       3.675
# x1             2.0126      0.032     62.191      0.000       1.910       2.116
# x2             4.9641      0.026    190.864      0.000       4.881       5.047
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.678
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.766
# Skew:                          -0.277   Prob(JB):                        0.682
# Kurtosis:                       1.339   Cond. No.                         19.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
faj_path = "../database/cleaned/merged_faj2015_2020.csv"

faj_df = pd.read_csv(faj_path, index_col=0)
faj_df
# Out:
#             Budget FAJ (en euros)  \
# Ain                     457200.00
# Allier                  198034.00
# Ardèche                 271930.93
# Cantal                  108000.00
# Drôme                   505023.39
# ...                           ...
# Guadeloupe              380267.34
# Martinique              355000.00
# Guyane                  255074.04
# La Réunion              400000.00
# Mayotte                       NaN
#
#             Montant des aides individuelles attribuées (en euros)  \
# Ain                                                 252328.00
# Allier                                              147222.06
# Ardèche                                             152403.00
# Cantal                                               32147.30
# Drôme                                               196800.26
# ...                                                       ...
# Guadeloupe                                          344722.03
# Martinique                                                NaN
# Guyane                                              234381.00
# La Réunion                                          211471.15
# Mayotte                                                   NaN
#
#             Nombre d'aides individuelles attribuées (2)  \
# Ain                                              1520.0
# Allier                                           1397.0
# Ardèche                                          1203.0
# Cantal                                            195.0
# Drôme                                             891.0
# ...                                                 ...
# Guadeloupe                                       1661.0
# Martinique                                        704.0
# Guyane                                            490.0
# La Réunion                                       1152.0
# Mayotte                                             NaN
#
#             Montant moyen de l'aide individuelle attribuée (en euros)  \
# Ain                                                    166.01
# Allier                                                 105.38
# Ardèche                                                126.69
# Cantal                                                 164.86
# Drôme                                                  220.88
# ...                                                       ...
# Guadeloupe                                             207.54
# Martinique                                                NaN
# Guyane                                                 478.33
# La Réunion                                             183.57
# Mayotte                                                   NaN
#
#             Nombre de bénéficiaires du FAJ  \
# Ain                                  971.0
# Allier                               778.0
# Ardèche                              694.0
# Cantal                               155.0
# Drôme                                845.0
# ...                                    ...
# Guadeloupe                           616.0
# Martinique                           704.0
# Guyane                               490.0
# La Réunion                          1019.0
# Mayotte                                NaN
#
#             Part de l'ensemble des jeunes de 20 à 24 ans vivant chez les parents en %  \
# Ain                                                     55.59
# Allier                                                  40.77
# Ardèche                                                 53.46
# Cantal                                                  42.94
# Drôme                                                   51.33
# ...                                                       ...
# Guadeloupe                                              70.90
# Martinique                                              73.64
# Guyane                                                  50.97
# La Réunion                                              60.64
# Mayotte                                                   NaN
#
#             Population étudiante  Taux pauvreté département  \
# Ain                       3183.0                       10.5
# Allier                    3857.0                       15.3
# Ardèche                   1415.0                       14.3
# Cantal                    1431.0                       13.2
# Drôme                     7920.0                       14.4
# ...                          ...                        ...
# Guadeloupe                9603.0                       34.5
# Martinique                8628.0                       26.7
# Guyane                    4250.0                       53.0
# La Réunion               21426.0                       35.6
# Mayotte                   1655.0                       77.0
#
#             Population étudiante sous le seuil de pauvreté  \
# Ain                                                334.215
# Allier                                             590.121
# Ardèche                                            202.345
# Cantal                                             188.892
# Drôme                                             1140.480
# ...                                                    ...
# Guadeloupe                                        3313.000
# Martinique                                        2303.676
# Guyane                                            2252.000
# La Réunion                                        7627.656
# Mayotte                                           1274.000
#
#             Loyer moyen m2 appartement  Loyer moyen m2 maison  \
# Ain                               13.6                   13.7
# Allier                            10.8                    9.8
# Ardèche                           10.4                   11.0
# Cantal                             9.6                    9.7
# Drôme                             11.3                   11.9
# ...                                ...                    ...
# Guadeloupe                        12.0                   13.0
# Martinique                        12.0                   13.0
# Guyane                            13.0                   14.0
# La Réunion                        10.0                   12.0
# Mayotte                           13.0                   13.0
#
#             Consommation énergétique moyenne (MWh)  Niveau de vie median
# Ain                                       4.395064               24030.0
# Allier                                    5.073961               20990.0
# Ardèche                                   3.696739               21450.0
# Cantal                                    3.434983               21140.0
# Drôme                                     4.125586               21790.0
# ...                                            ...                   ...
# Guadeloupe                                1.883515               18000.0
# Martinique                                1.688178               19200.0
# Guyane                                    1.125110               11000.0
# La Réunion                                1.474097               16520.0
# Mayotte                                   0.666353                9000.0
#
# [101 rows x 13 columns]

# %%
faj_df.columns = ["x1","x2","x3","x4","x5","x6","x7","x8","y","x9", "x10", "x11","x12"]

# %%
faj_df
# Out:
#                    x1         x2      x3      x4      x5     x6       x7  \
# Ain         457200.00  252328.00  1520.0  166.01   971.0  55.59   3183.0
# Allier      198034.00  147222.06  1397.0  105.38   778.0  40.77   3857.0
# Ardèche     271930.93  152403.00  1203.0  126.69   694.0  53.46   1415.0
# Cantal      108000.00   32147.30   195.0  164.86   155.0  42.94   1431.0
# Drôme       505023.39  196800.26   891.0  220.88   845.0  51.33   7920.0
# ...               ...        ...     ...     ...     ...    ...      ...
# Guadeloupe  380267.34  344722.03  1661.0  207.54   616.0  70.90   9603.0
# Martinique  355000.00        NaN   704.0     NaN   704.0  73.64   8628.0
# Guyane      255074.04  234381.00   490.0  478.33   490.0  50.97   4250.0
# La Réunion  400000.00  211471.15  1152.0  183.57  1019.0  60.64  21426.0
# Mayotte           NaN        NaN     NaN     NaN     NaN    NaN   1655.0
#
#               x8         y    x9   x10       x11      x12
# Ain         10.5   334.215  13.6  13.7  4.395064  24030.0
# Allier      15.3   590.121  10.8   9.8  5.073961  20990.0
# Ardèche     14.3   202.345  10.4  11.0  3.696739  21450.0
# Cantal      13.2   188.892   9.6   9.7  3.434983  21140.0
# Drôme       14.4  1140.480  11.3  11.9  4.125586  21790.0
# ...          ...       ...   ...   ...       ...      ...
# Guadeloupe  34.5  3313.000  12.0  13.0  1.883515  18000.0
# Martinique  26.7  2303.676  12.0  13.0  1.688178  19200.0
# Guyane      53.0  2252.000  13.0  14.0  1.125110  11000.0
# La Réunion  35.6  7627.656  10.0  12.0  1.474097  16520.0
# Mayotte     77.0  1274.000  13.0  13.0  0.666353   9000.0
#
# [101 rows x 13 columns]

# %%
model = statsmodels.formula.api.ols('y ~ x1 + x2 + x3 + x4 + x5 + x6 + x9 + x11 + x12', data = faj_df)
result = model.fit()

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     34.74
# Date:                Sun, 17 Nov 2024   Prob (F-statistic):           2.06e-22
# Time:                        21:09:37   Log-Likelihood:                -760.11
# No. Observations:                  80   AIC:                             1540.
# Df Residuals:                      70   BIC:                             1564.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5336.6251   5926.495      0.900      0.371   -6483.396    1.72e+04
# x1            -0.0014      0.002     -0.927      0.357      -0.004       0.002
# x2             0.0198      0.006      3.166      0.002       0.007       0.032
# x3            -1.9186      0.725     -2.647      0.010      -3.364      -0.473
# x4           -12.1262      7.584     -1.599      0.114     -27.252       3.000
# x5             0.3243      1.755      0.185      0.854      -3.176       3.824
# x6          -234.9917     52.725     -4.457      0.000    -340.148    -129.835
# x9          1880.9156    171.182     10.988      0.000    1539.504    2222.327
# x11          475.2285    726.140      0.654      0.515    -973.013    1923.470
# x12           -0.7043      0.300     -2.350      0.022      -1.302      -0.106
# ==============================================================================
# Omnibus:                       18.138   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.452
# Skew:                           0.848   Prob(JB):                     1.48e-07
# Kurtosis:                       5.561   Cond. No.                     1.06e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
