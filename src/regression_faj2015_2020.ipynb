# %% [markdown]
# # main imports

# %%
import os
import pandas as pd 
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
from tqdm import tqdm
from collections import defaultdict
import numpy as np
import statsmodels.formula.api



pd.options.display.max_columns = 200
pd.options.display.max_rows = 50

# %%
df = pd.DataFrame({'x1': [2, 6, 7, 8, 6, 2], 'x2': [4, 2, 9, 1, 7, 2]})
df['y'] = df['x1'] * 2 + df['x2'] * 5 + 0.2 * np.random.randn(len(df)) + 3
model = statsmodels.formula.api.ols('y ~ x1 + x2', data = df)
result = model.fit()

# %%
result.summary()
# Out:
# c:\Users\james\OneDrive\Documents\french_student_precariousness_in_conometrics\.venv\lib\site-packages\statsmodels\stats\stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.371e+04
# Date:                Sun, 17 Nov 2024   Prob (F-statistic):           1.14e-06
# Time:                        16:25:46   Log-Likelihood:                 2.1810
# No. Observations:                   6   AIC:                             1.638
# Df Residuals:                       3   BIC:                             1.013
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.1407      0.256     12.281      0.001       2.327       3.955
# x1             1.9862      0.042     46.949      0.000       1.852       2.121
# x2             4.9917      0.034    146.818      0.000       4.884       5.100
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.902
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.645
# Skew:                           0.677   Prob(JB):                        0.724
# Kurtosis:                       2.134   Cond. No.                         19.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
faj_path = "../database/cleaned/merged_faj2015_2020.csv"

faj_df = pd.read_csv(faj_path, index_col=0)
faj_df
# Out:
#             Budget FAJ (en euros)  \
# Ain                     457200.00
# Allier                  198034.00
# Ardèche                 271930.93
# Cantal                  108000.00
# Drôme                   505023.39
# ...                           ...
# Guadeloupe              380267.34
# Martinique              355000.00
# Guyane                  255074.04
# La Réunion              400000.00
# Mayotte                       NaN
#
#             Montant des aides individuelles attribuées (en euros)  \
# Ain                                                 252328.00
# Allier                                              147222.06
# Ardèche                                             152403.00
# Cantal                                               32147.30
# Drôme                                               196800.26
# ...                                                       ...
# Guadeloupe                                          344722.03
# Martinique                                                NaN
# Guyane                                              234381.00
# La Réunion                                          211471.15
# Mayotte                                                   NaN
#
#             Nombre d'aides individuelles attribuées (2)  \
# Ain                                              1520.0
# Allier                                           1397.0
# Ardèche                                          1203.0
# Cantal                                            195.0
# Drôme                                             891.0
# ...                                                 ...
# Guadeloupe                                       1661.0
# Martinique                                        704.0
# Guyane                                            490.0
# La Réunion                                       1152.0
# Mayotte                                             NaN
#
#             Montant moyen de l'aide individuelle attribuée (en euros)  \
# Ain                                                    166.01
# Allier                                                 105.38
# Ardèche                                                126.69
# Cantal                                                 164.86
# Drôme                                                  220.88
# ...                                                       ...
# Guadeloupe                                             207.54
# Martinique                                                NaN
# Guyane                                                 478.33
# La Réunion                                             183.57
# Mayotte                                                   NaN
#
#             Nombre de bénéficiaires du FAJ  \
# Ain                                  971.0
# Allier                               778.0
# Ardèche                              694.0
# Cantal                               155.0
# Drôme                                845.0
# ...                                    ...
# Guadeloupe                           616.0
# Martinique                           704.0
# Guyane                               490.0
# La Réunion                          1019.0
# Mayotte                                NaN
#
#             Part de l'ensemble des jeunes de 20 à 24 ans vivant chez les parents en %  \
# Ain                                                     55.59
# Allier                                                  40.77
# Ardèche                                                 53.46
# Cantal                                                  42.94
# Drôme                                                   51.33
# ...                                                       ...
# Guadeloupe                                              70.90
# Martinique                                              73.64
# Guyane                                                  50.97
# La Réunion                                              60.64
# Mayotte                                                   NaN
#
#             Population étudiante  Taux pauvreté département  \
# Ain                       3183.0                       10.5
# Allier                    3857.0                       15.3
# Ardèche                   1415.0                       14.3
# Cantal                    1431.0                       13.2
# Drôme                     7920.0                       14.4
# ...                          ...                        ...
# Guadeloupe                9603.0                        NaN
# Martinique                8628.0                       26.7
# Guyane                    4250.0                        NaN
# La Réunion               21426.0                       35.6
# Mayotte                   1655.0                        NaN
#
#             Population étudiante sous le seuil de pauvreté  \
# Ain                                                334.215
# Allier                                             590.121
# Ardèche                                            202.345
# Cantal                                             188.892
# Drôme                                             1140.480
# ...                                                    ...
# Guadeloupe                                           0.000
# Martinique                                        2303.676
# Guyane                                               0.000
# La Réunion                                        7627.656
# Mayotte                                              0.000
#
#             Loyer moyen m2 appartement  Loyer moyen m2 maison  \
# Ain                               13.6                   13.7
# Allier                            10.8                    9.8
# Ardèche                           10.4                   11.0
# Cantal                             9.6                    9.7
# Drôme                             11.3                   11.9
# ...                                ...                    ...
# Guadeloupe                        12.0                   13.0
# Martinique                        12.0                   13.0
# Guyane                            13.0                   14.0
# La Réunion                        10.0                   12.0
# Mayotte                           13.0                   13.0
#
#             Consommation énergétique moyenne
# Ain                                 4.395064
# Allier                              5.073961
# Ardèche                             3.696739
# Cantal                              3.434983
# Drôme                               4.125586
# ...                                      ...
# Guadeloupe                          1.883515
# Martinique                          1.688178
# Guyane                              1.125110
# La Réunion                          1.474097
# Mayotte                             0.666353
#
# [101 rows x 12 columns]

# %%
faj_df.columns = ["x1","x2","x3","x4","x5","x6","x7","x8","y","x9", "x10", "x11"]

# %%
faj_df
# Out:
#                    x1         x2      x3      x4      x5     x6       x7  \
# Ain         457200.00  252328.00  1520.0  166.01   971.0  55.59   3183.0
# Allier      198034.00  147222.06  1397.0  105.38   778.0  40.77   3857.0
# Ardèche     271930.93  152403.00  1203.0  126.69   694.0  53.46   1415.0
# Cantal      108000.00   32147.30   195.0  164.86   155.0  42.94   1431.0
# Drôme       505023.39  196800.26   891.0  220.88   845.0  51.33   7920.0
# ...               ...        ...     ...     ...     ...    ...      ...
# Guadeloupe  380267.34  344722.03  1661.0  207.54   616.0  70.90   9603.0
# Martinique  355000.00        NaN   704.0     NaN   704.0  73.64   8628.0
# Guyane      255074.04  234381.00   490.0  478.33   490.0  50.97   4250.0
# La Réunion  400000.00  211471.15  1152.0  183.57  1019.0  60.64  21426.0
# Mayotte           NaN        NaN     NaN     NaN     NaN    NaN   1655.0
#
#               x8         y    x9   x10       x11
# Ain         10.5   334.215  13.6  13.7  4.395064
# Allier      15.3   590.121  10.8   9.8  5.073961
# Ardèche     14.3   202.345  10.4  11.0  3.696739
# Cantal      13.2   188.892   9.6   9.7  3.434983
# Drôme       14.4  1140.480  11.3  11.9  4.125586
# ...          ...       ...   ...   ...       ...
# Guadeloupe   NaN     0.000  12.0  13.0  1.883515
# Martinique  26.7  2303.676  12.0  13.0  1.688178
# Guyane       NaN     0.000  13.0  14.0  1.125110
# La Réunion  35.6  7627.656  10.0  12.0  1.474097
# Mayotte      NaN     0.000  13.0  13.0  0.666353
#
# [101 rows x 12 columns]

# %%
model = statsmodels.formula.api.ols('y ~ x4 + x5 + x6 + x9 + x11', data = faj_df)
result = model.fit()

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                     44.50
# Date:                Sun, 17 Nov 2024   Prob (F-statistic):           3.20e-21
# Time:                        16:38:40   Log-Likelihood:                -792.23
# No. Observations:                  82   AIC:                             1596.
# Df Residuals:                      76   BIC:                             1611.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3073.7585   4345.012     -0.707      0.481   -1.17e+04    5580.082
# x4             5.8260      5.561      1.048      0.298      -5.249      16.901
# x5             3.2251      0.619      5.206      0.000       1.991       4.459
# x6          -282.9200     56.398     -5.017      0.000    -395.246    -170.594
# x9          1543.3799    148.206     10.414      0.000    1248.201    1838.558
# x11         -735.4268    649.190     -1.133      0.261   -2028.402     557.548
# ==============================================================================
# Omnibus:                       23.614   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.929
# Skew:                           0.855   Prob(JB):                     1.78e-15
# Kurtosis:                       7.118   Cond. No.                     1.22e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.22e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
